# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import nltk
import future
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.preprocessing import label_binarize
from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.svm import SVR
from sklearn import metrics

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from bs4 import BeautifulSoup  
import re
import nltk
from nltk.corpus import stopwords

# %%
data = pd.read_csv("/content/drive/MyDrive/data/Mobile_up.csv", encoding='latin1')
data.head()
# Out:
#    Unnamed: 0                                     Product Name  Brand  \
# 0           0   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 1           1   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 2           2   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 3           4                   Apple iPhone 12 (128GB) - Blue  Apple
# 4           5                   Apple iPhone 12 (128GB) - Blue  Apple
#
#                                              Reviews  Rating  \
# 0                                     Just excellent       5
# 1               Currently the best phone Apple makes       5
# 2  This took one of my kidneys and a testicle. Bu...       5
# 3             Best Premium Smartphone in all aspects       5
# 4                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis  Label
# 0                          excellent       1.0  Positive      1
# 1    Currently best phone Apple make       1.0  Positive      1
# 2     take one kidney testicle worth       0.3  Positive      1
# 3     Best Premium Smartphone aspect       1.0  Positive      1
# 4                        Best iPhone       1.0  Positive      1

# %%
text = pd.read_csv("/content/drive/MyDrive/data/App_rev.csv", encoding='latin1')
text.head()
# Out:
#                                       Product Name  Brand   Price  Rating  \
# 0   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple  1199.0       5
# 1   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple  1199.0       5
# 2   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple  1199.0       5
# 3                   Apple iPhone 12 (128GB) - Blue  Apple   749.0       5
# 4                   Apple iPhone 12 (128GB) - Blue  Apple   749.0       5
#
#                                              Reviews  Analysis  Label
# 0                                     Just excellent  Positive      1
# 1               Currently the best phone Apple makes  Positive      1
# 2  This took one of my kidneys and a testicle. Bu...  Positive      1
# 3             Best Premium Smartphone in all aspects  Positive      1
# 4                                        Best iPhone  Positive      1

# %%
mydata = data
mydata.head()
# Out:
#    Unnamed: 0                                     Product Name  Brand  \
# 0           0   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 1           1   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 2           2   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 3           4                   Apple iPhone 12 (128GB) - Blue  Apple
# 4           5                   Apple iPhone 12 (128GB) - Blue  Apple
#
#                                              Reviews  Rating  \
# 0                                     Just excellent       5
# 1               Currently the best phone Apple makes       5
# 2  This took one of my kidneys and a testicle. Bu...       5
# 3             Best Premium Smartphone in all aspects       5
# 4                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis  Label
# 0                          excellent       1.0  Positive      1
# 1    Currently best phone Apple make       1.0  Positive      1
# 2     take one kidney testicle worth       0.3  Positive      1
# 3     Best Premium Smartphone aspect       1.0  Positive      1
# 4                        Best iPhone       1.0  Positive      1

# %%
mydata.shape
# Out:
# (99442, 9)

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99442 entries, 0 to 99441
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    99442 non-null  int64
#  1   Product Name  99442 non-null  object
#  2   Brand         99442 non-null  object
#  3   Reviews       99442 non-null  object
#  4   Rating        99442 non-null  int64
#  5   Lemma         99442 non-null  object
#  6   Polarity      99442 non-null  float64
#  7   Analysis      99442 non-null  object
#  8   Label         99442 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 6.8+ MB

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ###Missing Values Imputation

# %%
# Let's see which number of rows consist missing values for 'Reviews' column 
mydata[mydata['Reviews'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Product Name, Brand, Reviews, Rating, Lemma, Polarity, Analysis, Label]
# Index: []

# %% [markdown]
# ### Cleaning Text

# %%
# Define a function to clean the text
import re
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', str(text))
    return text

# Cleaning the text in the review column
mydata['Cleaned Reviews'] = mydata['Reviews'].apply(clean)
mydata.head()
# Out:
#    Unnamed: 0                                     Product Name  Brand  \
# 0           0   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 1           1   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 2           2   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 3           4                   Apple iPhone 12 (128GB) - Blue  Apple
# 4           5                   Apple iPhone 12 (128GB) - Blue  Apple
#
#                                              Reviews  Rating  \
# 0                                     Just excellent       5
# 1               Currently the best phone Apple makes       5
# 2  This took one of my kidneys and a testicle. Bu...       5
# 3             Best Premium Smartphone in all aspects       5
# 4                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis  Label  \
# 0                          excellent       1.0  Positive      1
# 1    Currently best phone Apple make       1.0  Positive      1
# 2     take one kidney testicle worth       0.3  Positive      1
# 3     Best Premium Smartphone aspect       1.0  Positive      1
# 4                        Best iPhone       1.0  Positive      1
#
#                                      Cleaned Reviews
# 0                                     Just excellent
# 1               Currently the best phone Apple makes
# 2  This took one of my kidneys and a testicle But...
# 3             Best Premium Smartphone in all aspects
# 4                                        Best iPhone

# %% [markdown]
# ### Tokenize, Stop-words, pos

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet

# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
        
    return newlist

mydata['POS tagged'] = mydata['Cleaned Reviews'].apply(token_stop_pos)
mydata.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
#    Unnamed: 0                                     Product Name  Brand  \
# 0           0   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 1           1   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 2           2   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 3           4                   Apple iPhone 12 (128GB) - Blue  Apple
# 4           5                   Apple iPhone 12 (128GB) - Blue  Apple
#
#                                              Reviews  Rating  \
# 0                                     Just excellent       5
# 1               Currently the best phone Apple makes       5
# 2  This took one of my kidneys and a testicle. Bu...       5
# 3             Best Premium Smartphone in all aspects       5
# 4                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis  Label  \
# 0                          excellent       1.0  Positive      1
# 1    Currently best phone Apple make       1.0  Positive      1
# 2     take one kidney testicle worth       0.3  Positive      1
# 3     Best Premium Smartphone aspect       1.0  Positive      1
# 4                        Best iPhone       1.0  Positive      1
#
#                                      Cleaned Reviews  \
# 0                                     Just excellent
# 1               Currently the best phone Apple makes
# 2  This took one of my kidneys and a testicle But...
# 3             Best Premium Smartphone in all aspects
# 4                                        Best iPhone
#
#                                           POS tagged
# 0                                   [(excellent, n)]
# 1  [(Currently, r), (best, a), (phone, n), (Apple...
# 2  [(took, v), (one, None), (kidneys, n), (testic...
# 3  [(Best, n), (Premium, n), (Smartphone, n), (as...
# 4                           [(Best, n), (iPhone, n)]

# %% [markdown]
# # Obtaining the stem words – Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos:
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

mydata['Lemma'] = mydata['POS tagged'].apply(lemmatize)
mydata.head()
# Out:
#    Unnamed: 0                                     Product Name  Brand  \
# 0           0   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 1           1   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 2           2   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple
# 3           4                   Apple iPhone 12 (128GB) - Blue  Apple
# 4           5                   Apple iPhone 12 (128GB) - Blue  Apple
#
#                                              Reviews  Rating  \
# 0                                     Just excellent       5
# 1               Currently the best phone Apple makes       5
# 2  This took one of my kidneys and a testicle. Bu...       5
# 3             Best Premium Smartphone in all aspects       5
# 4                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis  Label  \
# 0                          excellent       1.0  Positive      1
# 1    Currently best phone Apple make       1.0  Positive      1
# 2     take one kidney testicle worth       0.3  Positive      1
# 3     Best Premium Smartphone aspect       1.0  Positive      1
# 4                        Best iPhone       1.0  Positive      1
#
#                                      Cleaned Reviews  \
# 0                                     Just excellent
# 1               Currently the best phone Apple makes
# 2  This took one of my kidneys and a testicle But...
# 3             Best Premium Smartphone in all aspects
# 4                                        Best iPhone
#
#                                           POS tagged
# 0                                   [(excellent, n)]
# 1  [(Currently, r), (best, a), (phone, n), (Apple...
# 2  [(took, v), (one, None), (kidneys, n), (testic...
# 3  [(Best, n), (Premium, n), (Smartphone, n), (as...
# 4                           [(Best, n), (iPhone, n)]

# %%
mydata[['Reviews','Lemma']]
# Out:
#                                                  Reviews  \
# 0                                         Just excellent
# 1                   Currently the best phone Apple makes
# 2      This took one of my kidneys and a testicle. Bu...
# 3                 Best Premium Smartphone in all aspects
# 4                                            Best iPhone
# ...                                                  ...
# 99437  Stopped turning on within 3 days. With no warr...
# 99438                                   Came as expected
# 99439                                   Bad. Azz. Phone.
# 99440  Love the phone, great screen, fast, slim but d...
# 99441  this product is terrible ...i wud advise no bu...
#
#                                                    Lemma
# 0                                              excellent
# 1                        Currently best phone Apple make
# 2                         take one kidney testicle worth
# 3                         Best Premium Smartphone aspect
# 4                                            Best iPhone
# ...                                                  ...
# 99437    Stopped turn within day warranty royally f e...
# 99438                                        Came expect
# 99439                                      Bad Azz Phone
# 99440    Love phone great screen fast slim dislike Mo...
# 99441    product terrible wud advise buyer buy produc...
#
# [99442 rows x 2 columns]

# %% [markdown]
# ### Look at the Lemma text using wordcloud

# %%
! pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
# Create a new data frame 'reviewss' to perform exploratory data analysis on that
reviewss = mydata
# dropping null values
reviewss.dropna(inplace = True)

# %%
# wordcloud function's need to be a single string of text
# concatenating all reviews in a single string
reviewss_str = reviewss.Lemma.str.cat()
wordcloud = WordCloud(background_color='white').generate(reviewss_str)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Sentiment Analysis using TextBlob:

# %%
from textblob import TextBlob
# function to calculate subjectivity
def getSubjectivity(review):
    return TextBlob(review).sentiment.subjectivity
    # function to calculate polarity
def getPolarity(review):
    return TextBlob(review).sentiment.polarity

i = -1
# function to analyze the reviews
def analysis(score):
    global i
    i = i+1
    if score > 0 and fin_data['Rating'][i] >3:
      return 'Positive'
    elif score == 0 and fin_data['Rating'][i] == 3:
      return 'Neutral'             
    else:
      return 'Negative'

# %%
fin_data = pd.DataFrame(mydata[['Brand','Reviews','Rating','Lemma']])

# %%
# fin_data['Subjectivity'] = fin_data['Lemma'].apply(getSubjectivity) 
fin_data['Polarity'] = fin_data['Lemma'].apply(getPolarity) 
fin_data['Analysis'] = fin_data['Polarity'].apply(analysis)
fin_data.head()
# Out:
#    Brand                                            Reviews  Rating  \
# 0  Apple                                     Just excellent       5
# 1  Apple               Currently the best phone Apple makes       5
# 2  Apple  This took one of my kidneys and a testicle. Bu...       5
# 3  Apple             Best Premium Smartphone in all aspects       5
# 4  Apple                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis
# 0                          excellent       1.0  Positive
# 1    Currently best phone Apple make       1.0  Positive
# 2     take one kidney testicle worth       0.3  Positive
# 3     Best Premium Smartphone aspect       1.0  Positive
# 4                        Best iPhone       1.0  Positive

# %% [markdown]
# Removing Neutral Values

# %%
fin_data = fin_data[fin_data.Analysis != 'Neutral']

# %% [markdown]
# ### Count the number of positive, negative, neutral reviews.

# %%
tb_counts = fin_data.Analysis.value_counts()
tb_counts
# Out:
# Positive    49721
# Negative    49721
# Name: Analysis, dtype: int64

# %%
tb_apple_counts = fin_data[(fin_data.Brand)=='Apple'].Analysis.value_counts()
tb_apple_counts
# Out:
# Positive    19948
# Negative    18590
# Name: Analysis, dtype: int64

# %%
tb_samsung_counts = fin_data[(fin_data.Brand)=='Samsung'].Analysis.value_counts()
tb_samsung_counts
# Out:
# Negative    20617
# Positive    18156
# Name: Analysis, dtype: int64

# %%
tb_htc_counts = fin_data[(fin_data.Brand)=='HTC'].Analysis.value_counts()
tb_htc_counts
# Out:
# Negative    3646
# Positive    2773
# Name: Analysis, dtype: int64

# %%
tb_sony_counts = fin_data[(fin_data.Brand)=='Sony'].Analysis.value_counts()
tb_sony_counts
# Out:
# Positive    5360
# Negative    4318
# Name: Analysis, dtype: int64

# %%
fin_data[(fin_data.Brand)=='Huawei'].Analysis.value_counts()
# Out:
# Positive    2933
# Negative    1363
# Name: Analysis, dtype: int64

# %%
fin_data[(fin_data.Brand)=='Asus'].Analysis.value_counts()
# Out:
# Negative    914
# Positive    452
# Name: Analysis, dtype: int64

# %%
fin_data.head()
# Out:
#    Brand                                            Reviews  Rating  \
# 0  Apple                                     Just excellent       5
# 1  Apple               Currently the best phone Apple makes       5
# 2  Apple  This took one of my kidneys and a testicle. Bu...       5
# 3  Apple             Best Premium Smartphone in all aspects       5
# 4  Apple                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis
# 0                          excellent       1.0  Positive
# 1    Currently best phone Apple make       1.0  Positive
# 2     take one kidney testicle worth       0.3  Positive
# 3     Best Premium Smartphone aspect       1.0  Positive
# 4                        Best iPhone       1.0  Positive

# %%
labels = []
for cell in fin_data['Analysis']:
  if cell == 'Positive':
    labels.append('1')    
  else:
    labels.append('0')   

fin_data['Label'] = labels

# %%
fin_data.head()
# Out:
#    Brand                                            Reviews  Rating  \
# 0  Apple                                     Just excellent       5
# 1  Apple               Currently the best phone Apple makes       5
# 2  Apple  This took one of my kidneys and a testicle. Bu...       5
# 3  Apple             Best Premium Smartphone in all aspects       5
# 4  Apple                                        Best iPhone       5
#
#                                Lemma  Polarity  Analysis Label
# 0                          excellent       1.0  Positive     1
# 1    Currently best phone Apple make       1.0  Positive     1
# 2     take one kidney testicle worth       0.3  Positive     1
# 3     Best Premium Smartphone aspect       1.0  Positive     1
# 4                        Best iPhone       1.0  Positive     1

# %%
from sklearn.model_selection import train_test_split
#split data into training and testing set
x_train, x_test, y_train, y_test = train_test_split(fin_data['Lemma'], fin_data['Label'], test_size=0.2, random_state=0)

# %% [markdown]
# #Apple VS Samsung using Random Forest

# %% [markdown]
# ####Apple

# %%
apple = pd.read_csv('/content/drive/MyDrive/data/App_rev.csv')
apple.head()
# Out:
#                                       Product Name  Brand   Price  Rating  \
# 0   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple  1199.0       5
# 1   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple  1199.0       5
# 2   Apple iPhone 12 Pro Max (256GB) - Pacific Blue  Apple  1199.0       5
# 3                   Apple iPhone 12 (128GB) - Blue  Apple   749.0       5
# 4                   Apple iPhone 12 (128GB) - Blue  Apple   749.0       5
#
#                                              Reviews  Analysis  Label
# 0                                     Just excellent  Positive      1
# 1               Currently the best phone Apple makes  Positive      1
# 2  This took one of my kidneys and a testicle. Bu...  Positive      1
# 3             Best Premium Smartphone in all aspects  Positive      1
# 4                                        Best iPhone  Positive      1

# %%
apple_test = apple['Reviews']

# %%
rand = RandomForestClassifier()
rand.fit(x_train_input, y_train)
y_rand_predicted = rand.predict(tfidf.transform(apple_test))

# %%
list_apple = y_rand_predicted.tolist()

# %%
apple_series = pd.Series( (v[0] for v in list_apple) )

# %%
apple_series.value_counts()
# Out:
# 1    30668
# 0    19588
# dtype: int64

# %%
apple_res = apple_series.value_counts()

# %% [markdown]
# ##Visualization for Apple Result

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,7))
plt.subplot(1,1,1)
plt.title("Apple results")
plt.pie(apple_res.values, labels = apple_res.index, autopct='%1.1f%%', shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3a791d9ed0>,
#   <matplotlib.patches.Wedge at 0x7f3a791a76d0>],
#  [Text(-0.3733775604107659, 1.0346928033874137, '1'),
#   Text(0.3733774635358327, -1.0346928383455392, '0')],
#  [Text(-0.2036604874967814, 0.564377892756771, '61.0%'),
#   Text(0.20366043465590872, -0.5643779118248395, '39.0%')])

# %% [markdown]
# ####Samsung

# %%
samsung = pd.read_csv('/content/drive/MyDrive/data/Sam_rev.csv')
samsung.head()
# Out:
#                 Product Name    Brand    Price  Rating  \
# 0        Samsung Galaxy S22   Samsung   799.99       4
# 1       Samsung Galaxy S22+   Samsung   999.99       4
# 2  Samsung Galaxy S22 Ultra   Samsung  1199.99       4
# 3     Samsung Galaxy A32 5G   Samsung   204.99       4
# 4     Samsung Galaxy S21 FE   Samsung   699.99       4
#
#                                              Reviews  Analysis  Label
# 0  The Samsung Galaxy S22 fits comfortably in one...  Positive      1
# 1  The Samsung Galaxy S22+ blends top-notch conne...  Positive      1
# 2  The S22 Ultra is the true successor to the Gal...  Positive      1
# 3  The Samsung Galaxy A32 5G's excellent battery ...  Positive      1
# 4  The Samsung Galaxy S21 FE is similar to the st...  Negative      0

# %%
samsung_test = samsung['Reviews']

# %%
rand = RandomForestClassifier()
rand.fit(x_train_input, y_train)
y_rand_predicted2 = rand.predict(tfidf.transform(samsung_test))

# %%
list_samsung = y_rand_predicted2.tolist()

# %%
samsung_series = pd.Series( (m[0] for m in list_samsung) )

# %%
samsung_series.value_counts()
# Out:
# 1    28298
# 0    21958
# dtype: int64

# %%
samsung_res = samsung_series.value_counts()

# %% [markdown]
# ##Visualization for Samsung Result

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,7))
plt.subplot(1,1,1)
plt.title("Samsung results")
plt.pie(samsung_res.values, labels = samsung_res.index, autopct='%1.1f%%', shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3a7dbc4850>,
#   <matplotlib.patches.Wedge at 0x7f3a7dbd2090>],
#  [Text(-0.21655476621584013, 1.0784730099678912, '1'),
#   Text(0.21655476621584027, -1.078473009967891, '0')],
#  [Text(-0.11812078157227643, 0.5882580054370314, '56.3%'),
#   Text(0.11812078157227648, -0.5882580054370314, '43.7%')])

# %% [markdown]
# ##Visualization for Apple & Samsung Result

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.title("Apple results")
plt.pie(apple_res.values, labels = apple_res.index, autopct='%1.1f%%', shadow=False)
plt.subplot(1,2,2)
plt.title("Samsung results")
plt.pie(samsung_res.values, labels = samsung_res.index, autopct='%1.1f%%', shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3a7daacb90>,
#   <matplotlib.patches.Wedge at 0x7f3a7dab6310>],
#  [Text(-0.21655476621584013, 1.0784730099678912, '1'),
#   Text(0.21655476621584027, -1.078473009967891, '0')],
#  [Text(-0.11812078157227643, 0.5882580054370314, '56.3%'),
#   Text(0.11812078157227648, -0.5882580054370314, '43.7%')])
